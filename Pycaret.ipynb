# %%
from pycaret.regression import *

train_data = pd.read_csv('train_cleaned_nonBool.csv', low_memory=False)
test_data = pd.read_csv('test_cleaned_nonBool.csv', low_memory=False)
prophet_preds = pd.read_csv('prophet_prediction.csv', low_memory=False)
train_data = train_data.merge(prophet_preds, on='date')
test_data = test_data.merge(prophet_preds, on='date')

s = setup(train_data.drop(columns=['ID','device','date']), target = 'pm2_5')
best = compare_models(budget_time=5)
print(best)
evaluate_model(best)
predictions = predict_model(best, data=test_data.drop(columns=['ID','device','date']))
predictions
# Out:
# C:\Users\USER\AppData\Roaming\Python\Python38\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            16:59:24
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#                                                    Data Type
# site_latitude                                        Numeric
# humidity                                             Numeric
# temp_mean                                            Numeric
# SulphurDioxide_cloud_fraction                        Numeric
# SulphurDioxide_sensor_azimuth_angle                  Numeric
# SulphurDioxide_sensor_zenith_angle                   Numeric
# SulphurDioxide_solar_azimuth_angle                   Numeric
# SulphurDioxide_solar_zenith_angle                    Numeric
# NitrogenDioxide_absorbing_aerosol_index              Numeric
# Ozone_O3_column_number_density                       Numeric
# Ozone_O3_effective_temperature                       Numeric
# Cloud_cloud_top_pressure                             Numeric
# Cloud_cloud_optical_depth                            Numeric
# Cloud_surface_albedo                                 Numeric
# SulphurDioxide_SO2_column_number_density_missing     Numeric
# SulphurDioxide_SO2_column_number_density_amf_mi...   Numeric
# CarbonMonoxide_CO_column_number_density_missing      Numeric
# CarbonMonoxide_H2O_column_number_density_missing     Numeric
# CarbonMonoxide_cloud_height_missing                  Numeric
# NitrogenDioxide_NO2_column_number_density_missing    Numeric
# NitrogenDioxide_stratospheric_NO2_column_number...   Numeric
# NitrogenDioxide_NO2_slant_column_number_density...   Numeric
# NitrogenDioxide_tropopause_pressure_missing          Numeric
# Formaldehyde_tropospheric_HCHO_column_number_de...   Numeric
# Formaldehyde_tropospheric_HCHO_column_number_de...   Numeric
# DF.L1.C1                                             Numeric
# DF.L1.C2                                             Numeric
# DF.L1.C3                                             Numeric
# DF.L1.C4                                             Numeric
# prophet_prediction                                   Numeric
# pm2_5                                                  Label

# %% [markdown]
# # Zindi

# %%
from pycaret.regression import *
import pandas as pd
import numpy as np
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

train_data = pd.read_csv('train_cleaned_nonBool.csv', low_memory=False)
test_data = pd.read_csv('test_cleaned_nonBool.csv', low_memory=False)
prophet_preds = pd.read_csv('prophet_prediction.csv', low_memory=False)
train_data = train_data.merge(prophet_preds, on='date')
test_data = test_data.merge(prophet_preds, on='date')

s = setup(train_data.drop(columns=['ID','device','date']), target = 'pm2_5')
best = compare_models(budget_time=5)
print(best)

preds = predict_model(best, data=test_data.drop(columns=['ID','device','date']))
preds = pd.DataFrame(preds).rename(columns={0:'pm2_5'})
test_data = test_data.join(preds)
test_data[['ID', 'pm2_5']].to_csv('zindi_pycaret.csv', index=False)

# %%
del train_data
del test_data
del preds
del automl

# %% [markdown]
# # Sber

# %%
from pycaret.regression import *
import pandas as pd
import numpy as np
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

train_data = pd.read_csv('train_sber.csv', low_memory=False)
test_data = pd.read_csv('test_sber.csv', low_memory=False)


s = setup(train_data.drop(columns=['id'], target = 'price_doc')
best = compare_models(budget_time=60)
print(best)

preds = predict_model(best, data=test_data.drop(columns=['id']))
preds = pd.DataFrame(preds).rename(columns={0:'price_doc'})
test_data = test_data.join(preds)
test_data[['id', 'price_doc']].to_csv('sber_pycaret.csv', index=False)

# %%
del train_data
del test_data
del preds
del automl

# %% [markdown]
# # Santander

# %%
from pycaret.classification import *
import pandas as pd
import numpy as np
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

train_data = pd.read_csv('train_santander.csv', low_memory=False)
test_data = pd.read_csv('test_santander.csv', low_memory=False)


s = setup(train_data.drop(columns=['ID'], target = 'TARGET')
best = compare_models(budget_time=60)
print(best)

preds = predict_model(best, data=test_data.drop(columns=['ID']))
preds = pd.DataFrame(preds).rename(columns={0:'TARGET'})
test_data = test_data.join(preds)
test_data[['ID', 'TARGET']].to_csv('santander_pycaret.csv', index=False)

# %%
del train_data
del test_data
del preds
del automl

# %% [markdown]
# # Liberty

# %%
from pycaret.regression import *
import pandas as pd
import numpy as np
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

train_data = pd.read_csv('train_liberty.csv', low_memory=False)
test_data = pd.read_csv('test_liberty.csv', low_memory=False)


s = setup(train_data.drop(columns=['id'], target = 'target')
best = compare_models(budget_time=60)
print(best)

preds = predict_model(best, data=test_data.drop(columns=['id']))
preds = pd.DataFrame(preds).rename(columns={0:'target'})
test_data = test_data.join(preds)
test_data[['id', 'target']].to_csv('liberty_pycaret.csv', index=False)

# %%
del train_data
del test_data
del preds
del automl

# %% [markdown]
# # Loan

# %%
from pycaret.regression import *
import pandas as pd
import numpy as np
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 500)

train_data = pd.read_csv('train_loan.csv', low_memory=False)
test_data = pd.read_csv('test_loan.csv', low_memory=False)


s = setup(train_data.drop(columns=['id'], target = 'loss')
best = compare_models(budget_time=60)
print(best)

preds = predict_model(best, data=test_data.drop(columns=['id']))
preds = pd.DataFrame(preds).rename(columns={0:'loss'})
test_data = test_data.join(preds)
test_data[['id', 'loss']].to_csv('loan_pycaret.csv', index=False)

# %%
del train_data
del test_data
del preds
del automl
